# %% [markdown]
# # Single neuron models
# By [Marcus Ghosh](https://profiles.imperial.ac.uk/m.ghosh/) & [Dan Goodman](https://neural-reckoning.org/)
#
# Based on an exercise from our [Neuro4ML](https://neuro4ml.github.io/) course.

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/trendinafrica/TReND-CaMinA/blob/main/notebooks/Rwanda24/13-Sat-CompNeuroIntro/Single_neuron_models.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# For Google Colab
if not os.path.exists('Data/test_current.csv'):
  # !git clone https://github.com/trendinafrica/TReND-CaMinA.git
  # %cd /content/TReND-CaMinA/notebooks/Rwanda24/13-Sat-CompNeuroIntro
# Out:
# fatal: destination path 'TReND-CaMinA' already exists and is not an empty directory.
# /content/TReND-CaMinA/notebooks/Rwanda24/13-Sat-CompNeuroIntro

# %% [markdown]
# ## Aim
# We're going to code an increasingly detailed model of a single neuron, then test how well this, and other models can approximate the spikes produced by a "real" neuron in response to a set of random input currents. This "real" neuron is actually just a complex model, but the idea is the same!
#
# The notebook is divided into three parts which you should work on together in pairs.
#
# **Model** - we'll start with code for an integrate-and-fire neuron, and add a number of features.
#
# **Testing** - we'll test how well this model is able to match data from the "real" neuron.
#
# Finally, we'll run a friendly **competition** to see which pair can best match the "real" neuron's data, using their own models.
#
# For the last 30mins of the session, each pair will summarise what they tried and there will be a small prize for the pair with the model which best approximates the "real" neuron.
#
# Good luck!

# %% [markdown]
# ## Model

# %% [markdown]
# ### Integrate-and-fire neuron
#
# We're going to start by looking at the code for a neuron model which simply integrates it's input's over time, spikes when it reaches a threshold and then resets to a baseline value.
#
# We'll define a function (neuron_model) which takes:
# * ``I`` - a numpy vector, with the input current at every time-step.
# * ``baseline`` - a float, which sets the baseline membrane potential. By default this will be 0.0.
# * ``threshold`` - a float, which sets the spiking threshold. By default this will be 1.0.
# * ``dt`` - a float, which sets the time between discrete simulation steps. As units we'll use milliseconds, and by default will set the time-step to be 0.1 (ms).
#
# Our function returns:
# * ``v`` - a numpy vector, with the output membrane potential at every time-step.
# * ``Spikes`` - a numpy vector with the recorded spike times.

# %%
def neuron_model(I, baseline=0.0, threshold=1.0, dt=0.1):

    time_steps = len(I) # the number of time-steps in the simulation
    v = np.ones(time_steps) * baseline # membrane potential
    spikes = [] # a list to store spike times

    for time in range(time_steps - 1):
        if v[time] > threshold:
            spikes.append(time * dt) # record spike time
            #time * dt converts the index time into the physical time in milliseconds.
            v[time] = baseline # reset membrane potential

        v[time + 1] = v[time] + I[time]*dt # update membrane potential
        #if a spike occurred, the integration for the next time step (time + 1)
        #correctly starts from the baseline potential, not from the high treshold ptential

        #I[time] * dt accounts for the accumulation of current over
        #that short duration to update the membrane potential.

    return v, np.array(spikes)

# %% [markdown]
# To see how our models behave we'll define a function to plot both the input current (``I``) and how our model responds: ``v`` and ``Spikes``.

# %%
def plot_model_response(I, v, spikes, dt=0.1):
    plt.plot(np.arange(len(I))*dt, I, color='xkcd:purple', linewidth=2, label='Input current')
    plt.plot(np.arange(len(I))*dt, v, color='xkcd:dark seafoam green', linewidth=2, label='Membrane potential')

    for i, t in enumerate(spikes):
        plt.axvline(t, c='xkcd:grey', lw=2, label='Spikes' if i==0 else None)

    plt.xlabel('Time (ms)')
    plt.ylabel('V')
    plt.legend()

# %% [markdown]
# Now we'll input a random current to our model.
#
# As an input we'll load a random current, which was input to our "real" neuron. That way we can easily see how each version of our model responds to the same input.

# %%
test_I = np.loadtxt('Data/test_current.csv') # shape (repeats, num_time_steps)
I = np.copy(test_I[0, :300]) # we'll use the input from the first repeat, and the first 30ms
I[50:100] = 0.0 # to see what our model's do without input, we'll also set the input, over some time-steps, to zero

v, spikes = neuron_model(I) # simulate
plot_model_response(I, v, spikes)

# %% [markdown]
# ### Adding a refractory period
#
# After spiking, real neurons enter a refractory period - during which they will not spike.
#
# One way to model this is to:
# * Add ``r_timer`` as a parameter to our function. This should be a float (e.g. 0.5) which sets the length of the refractory period (in ms).
# * Following each spike set a counter (``r_time``) to ``r_timer``.
# * Then for subsequent time steps, set ``v`` to baseline and decrease the timer by ``dt``, until the timer reaches zero.
#
# Copy the neuron model function from above into the cell below, edit it to include a refractory period and then try plotting it's response to the input current above.
#
# How does changing the length of the refractory period change the neuron's behaviour?

# %%
#refractory helps to decrease the freq of spikes by adding the hyperpolarazation concept
def neuron_model(I, baseline=0.0, threshold=1.0, dt=0.1, r_timer=0.5):

    time_steps = len(I) # the number of time-steps in the simulation
    v = np.ones(time_steps) * baseline # membrane potential
    spikes = [] # a list to store spike times
    r_time_left = 0.0 # Initialize refractory time left

    for time in range(time_steps - 1):
        # 1. Check for spike (only if not in refractory period)
        if r_time_left <= 0 and v[time] > threshold:
            spikes.append(time * dt) # record spike time
            v[time] = baseline # reset potential at time of spike
            r_time_left = r_timer # Start refractory period

        # 2. Apply refractory period effect for the *next* time step
        if r_time_left > 0:
            v[time + 1] = baseline # Force next potential to baseline
            r_time_left = max(0, r_time_left - dt) # Decrement refractory timer, ensure it doesn't go below 0
        else: # Not in refractory period, integrate
            v[time + 1] = v[time] + I[time]*dt # update membrane potential

    return v, np.array(spikes)

# %%
# If you are stuck or would like to check your answer you can:
# Check Solutions/refractory_period.py

# Or if you are running locally, you can:
# Uncomment and run the line below to load the solution.
# %load ./Solutions/refractory_period.py

# %%
# Plot model response
v, spikes = neuron_model(I, r_timer=2.0) # simulate with a refractory period of 2.0 ms
plot_model_response(I, v, spikes)

# %% [markdown]
# ### Adding a leak
#
# Rather than integrating and retaining their inputs indefinitely, real neuron's leak some current.
#
# This means that when they receive little or no input, their membrane potential will tend towards their baseline.
#
# Adding this leak will make our model a **leaky** integrate-and-fire neuron. This model's membrane potential changes over time as:
#
# $$ \tau \frac{dV}{dt} = I(t)-v $$
#
# Where:
# * $ \tau $ determines the rate of decay.
# * $ I(t) $ is the time-varying input current to the neuron.
# * $ v $ is the neuron's membrane potential.
#
# Copy your neuron model function from above into the cell below, then:
# * Add a parameter ``tau`` - the membrane time constant in ms. E.g. 5.
# * Find dV/dt (using the equation above).
# * Use dV/dt to update the membrane potential.
#
# Finally try plotting this model's response to the input current above.
#
# How does altering $ \tau $ change the neuron's behaviour?

# %%
#Enter your solution here
def neuron_model(I, baseline=0.0, threshold=1.0, dt=0.1, r_timer=0.5, tau=5.0):

    time_steps = len(I) # the number of time-steps in the simulation
    v = np.ones(time_steps) * baseline # membrane potential
    spikes = [] # a list to store spike times
    r_time_left = 0.0 # Initialize refractory time left

    for time in range(time_steps - 1):
        # 1. Check for spike (only if not in refractory period)
        if r_time_left <= 0 and v[time] > threshold:
            spikes.append(time * dt) # record spike time
            v[time] = baseline # reset potential at time of spike
            r_time_left = r_timer # Start refractory period

        # 2. Apply refractory period effect for the *next* time step
        if r_time_left > 0:
            v[time + 1] = baseline # Force next potential to baseline
            r_time_left = max(0, r_time_left - dt) # Decrement refractory timer, ensure it doesn't go below 0
        else: # Not in refractory period, integrate AND leak
            # Apply the leak equation: dv/dt = (I - v)/tau
            v[time + 1] = v[time] + (I[time] - v[time]) / tau * dt

    return v, np.array(spikes)

# %%
# If you are stuck or would like to check your answer you can:
# Check Solutions/leak.py

# Or if you are running locally, you can:
# Uncomment and run the line below to load the solution.
# %load ./Solutions/leak.py

# %%
# Plot model response
scale = 10 # Depending on how you implemented the leak, you may need to scale I to get your model to spike
v, spikes = neuron_model(I * scale, tau=5.0) # simulate with tau=5.0
plot_model_response(I, v, spikes)

# %% [markdown]
# ### Adding a dynamic threshold
#
# Many neuron's change their behaviour depending on their own recent activity.
#
# For example, in response to constant input they'll spike less and less frequently.
#
# One way to model this is to add a dynamic threshold.
#
# To do so:
# * Add a threshold increment parameter ``thr_i`` - following a spike we will increase our threshold by this amount (e.g. 2).
# * Add a threshold decay parameter ``thr_tau`` - at every time time-step we'll use this value (e.g. 50) to decay our threshold back to it's starting value (``threshold``)
#
# Again, copy your neuron model function from above, edit the code and then try plotting your model's response.
#
# How does changing these new parameters change the model's behaviour?

# %%
def neuron_model(I, baseline=0.0, threshold=1.0, dt=0.1, r_timer=0.5, tau=5.0, thr_i=2.0, thr_tau=50.0):

    time_steps = len(I) # the number of time-steps in the simulation
    v = np.ones(time_steps) * baseline # membrane potential
    spikes = [] # a list to store spike times
    r_time_left = 0.0 # Initialize refractory time left
    curr_threshold = threshold # Initialize dynamic threshold with the static threshold value

    for time in range(time_steps - 1):
        # 1. Check for spike (only if not in refractory period)
        if r_time_left <= 0 and v[time] > curr_threshold:
            spikes.append(time * dt) # record spike time
            v[time] = baseline # reset potential at time of spike
            r_time_left = r_timer # Start refractory period
            curr_threshold += thr_i # Increase threshold after a spike

        # 2. Apply refractory period effect for the *next* time step
        if r_time_left > 0:
            v[time + 1] = baseline # Force next potential to baseline
            r_time_left = max(0, r_time_left - dt) # Decrement refractory timer, ensure it doesn't go below 0
        else: # Not in refractory period, integrate AND leak
            # Apply the leak equation: dv/dt = (I - v)/tau
            v[time + 1] = v[time] + (I[time] - v[time]) / tau * dt

        # Apply threshold decay at every time step
        # curr_threshold decays back to the original `threshold`
        curr_threshold = curr_threshold + (threshold - curr_threshold) / thr_tau * dt

    return v, np.array(spikes)

# %%
# If you are stuck or would like to check your answer you can:
# Check Solutions/dynamic_threshold.py

# Or if you are running locally, you can:
# Uncomment and run the line below to load the solution.
# %load ./Solutions/dynamic_threshold.py

# %%
# Plot model response
v, spikes = neuron_model(I * scale, tau=5.0, thr_i=2.0, thr_tau=80.0) # simulate with dynamic threshold
plot_model_response(I, v, spikes)

# %% [markdown]
# # Testing
#
# ## Introduction
# Now we're going to see how well our model can approximate the spikes produced by a "real" neuron in response to a set of random input currents. Again, this "real" neuron is actually just a complex model, but the idea is the same!
#
# The data are split into **test** and **train** sets with three files each:
# * **Current** - the input currents that were injected into the neuron. A numpy array of shape repeats x time which we'll call ``I``.
#
# * **Traces** - the membrane potential response to each input current. A numpy array of shape repeats x time which we'll call ``v``.
#
# * **Spikes** - contains two numpy vectors which we'll term:
#     * ``spike_times`` - the time of each spike (in ms).
#     * ``spike_idx`` - which repeat each spike comes from.
#
# In each data set there are:
# * **Train** - 100 repeats, with 10,000 time steps each.
# * **Test** - 50 repeats, with 10,000 time steps each.
#
# We'll start by plotting the first 10 repeats from the train set. Note that we'll normalise the data so we can plot several repeats per plot.

# %%
# Load train data
train_I = np.loadtxt('Data/train_current.csv') # shape (repeats, num_time_steps)
train_v = np.loadtxt('Data/train_traces.csv') # shape (repeats, num_time_steps)
train_spike_times, train_spike_idx = np.loadtxt('Data/train_spikes.csv') # shape (num_spikes,)

repeats, num_time_steps = train_I.shape
state_t = np.arange(num_time_steps)*0.1 # in ms

def normalise(x):
    return (x-x.min())/(x.max()-x.min())

# Plotting
for idx_repeat in range(10):
    plt.plot(state_t, idx_repeat+0.9*normalise(train_I[idx_repeat, :]), color='xkcd:purple', label='Input current' if idx_repeat==0 else None)
    plt.plot(state_t, idx_repeat+0.9*normalise(train_v[idx_repeat, :]), color='xkcd:dark seafoam green', label='Membrane potential' if idx_repeat==0 else None)
plt.xlabel('Time (ms)')
plt.ylabel('Repeat index')
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ## Testing our model
#
# Now we're going to test how well our model approximates this "real" neuron's spiking.
#
# To do so, we will:
# * Input the same currents to our model,
# * Record it's spikes.
# * Then compare our model's spikes to those from the "real" neuron.
#
# First, we'll do this **qualitatively**, by taking the first 10 input currents, and plotting both our model and the "real" neuron's spikes.

# %%
def plot_approximation(neuron_spike_times, neuron_spike_idx, input_I):
    for idx_repeat in range(10):
        model_v, model_spikes = neuron_model(input_I[idx_repeat]) # simulate
        neuron_spikes = neuron_spike_times[neuron_spike_idx==idx_repeat] # get "real" spikes

        plt.scatter(model_spikes, idx_repeat*np.ones(len(model_spikes)), marker='.', color='xkcd:dark seafoam green', label='Neuron model' if idx_repeat==0 else None)
        plt.scatter(neuron_spikes, idx_repeat*np.ones(len(neuron_spikes))+0.2, marker='.', color='xkcd:purple', label='"Real" neuron' if idx_repeat==0 else None)

    plt.xlabel('Time (ms)')
    plt.ylabel('Repeat')
    plt.legend()

plot_approximation(train_spike_times, train_spike_idx, train_I)

# %% [markdown]
# Now we'll now compare our model **quantitively** to the "real" neuron.
#
# To do so we'll measure the [van Rossum distance](http://www.scholarpedia.org/article/Measures_of_spike_train_synchrony#van_Rossum_distance) between the spike trains from each using a pair of functions:
#
#  ``van_rossum_distance`` - returns the distance between two spike trains ``t0`` and ``t1`` over a given ``duration`` (all measured in ms).
#
#  ``mean_vr_distance`` - returns the mean distance between our model and the "real" neuron across our entire train or test set.
#
# Don't worry too much about this metric or these functions! All you need to know is that in our case a smaller van Rossum distance means a better match between a model and the "real" neuron.

# %%
def van_rossum_distance(t0, t1, duration, tau_vr=5, dt=0.1):
    # Note that tau_vr is not the same as the tau used in our neuron_model.
    n = int(np.round(duration/dt))
    x0 = np.zeros(n)
    x1 = np.zeros(n)
    for x, t in [(x0, t0), (x1, t1)]:
        x[np.array(np.round(t/dt), dtype=int)] = 1
    nk = int(np.round(3*tau_vr/dt))
    if 2*nk+1>n:
        nk = (n-1)//2
    T = np.arange(-nk, nk+1)*dt
    kernel = np.exp(-T/tau_vr)/tau_vr
    for x in [x0, x1]:
        x[:] = np.convolve(x, kernel, 'same')
    return np.sqrt(np.sum((x0-x1)**2*dt)/tau_vr)

# %%
def mean_vr_distance(neuron_spike_times, neuron_spike_idx, input_I, dt=0.1, plot_aprox=True,
                       baseline=0.0, threshold=1.0, r_timer=0.5, tau=5.0, thr_i=2.0, thr_tau=50.0, scale=10.0):
    duration=input_I.shape[1]*dt

    # Convert (t,i) format to list
    neuron_spikes, model_spikes = [], []
    for idx_repeat in range(input_I.shape[0]):

        # "Real" neuron
        n_spikes = neuron_spike_times[neuron_spike_idx==idx_repeat]
        neuron_spikes.append(neuron_spike_times[neuron_spike_idx==idx_repeat])

        # Model
        # Pass all parameters to the neuron_model call
        model_v, m_spikes = neuron_model(input_I[idx_repeat] * scale,
                                         baseline=baseline, threshold=threshold, dt=dt,
                                         r_timer=r_timer, tau=tau, thr_i=thr_i, thr_tau=thr_tau) # simulate
        model_spikes.append(m_spikes)

        # Plotting
        if (plot_aprox == True) & (idx_repeat < 10):
            plt.scatter(m_spikes, idx_repeat*np.ones(len(m_spikes)), marker='.', color='xkcd:dark seafoam green', label='Neuron model' if idx_repeat==0 else None)
            plt.scatter(n_spikes, idx_repeat*np.ones(len(n_spikes))+0.2, marker='.', color='xkcd:purple', label='"Real" neuron' if idx_repeat==0 else None)

            plt.xlabel('Time (ms)')
            plt.ylabel('Repeat')
            plt.legend()

    # Distance
    d = 0
    for t0, t1 in zip(neuron_spikes, model_spikes):
        d += van_rossum_distance(t0, t1, duration, dt=dt)
    d /= len(neuron_spikes)

    if plot_aprox == True:
        print("Distance: " + str(d))

    return d

# %%
d = mean_vr_distance(train_spike_times, train_spike_idx, train_I)
# Out:
# Distance: 15.829538835420962

# %% [markdown]
# The current mean Van Rossum distance with the default parameters is `16.93`. Now you can tune the parameters by passing them to the `mean_vr_distance` function. Remember, a smaller distance means a better approximation of the "real" neuron's spiking behavior.

# %% [markdown]
# ## Competition
#
# Finally, we're going to have a friendly **competition** to see which pair can best match the "real" neuron's data, using their own models. Then for the last 30mins of the session, each pair will summarise what they tried and there will be a small prize for the pair with the model which best approximates the "real" neuron.
#
# As a measure we'll use the mean van Rossum distance between the model and "real" neuron over the **test** set (using the ``mean_vr_distance`` function). Note that you should use the **train** data for model development, fitting etc.
#
# You are free to try whatever you like - though here are some ideas to get you started!
#
# * **Fitting model parameters** - throughout we've introduced several parameters to our model, guessing or even fitting different values for these could improve our approximation. For example, earlier we multiplied ``I`` by ``scale`` - we could add this to the ``mean_vr_distance`` function and test how changing it's value changes the approximation.
#
# * **Improving the neuron model** - real neurons have many complexities which we have simplified or overlooked. Improving how we have modelled these, or even adding new features could improve our model. For example, we have modelled the refractory period by simply setting the membrane potential to a baseline value, when in fact it *hyperpolarises* - dipping below baseline before returning.
#
# * **"Non-neuron" models** - in principle any model which accepts ``I`` and returns spikes could approximate our data. For example, you could train a recurrent neural network to do this.

# %%
# Define candidate values for r_timer, scale, tau, and thr_i
candidate_r_timers = [0.1, 0.3, 0.5, 0.7, 1.0]
candidate_scales = [8.0, 10.0, 12.0, 15.0, 18.0]
candidate_taus = [3.0, 5.0, 7.0, 10.0] # New parameter: tau for leak
candidate_thr_is = [1.0, 2.0, 3.0, 4.0] # New parameter: thr_i for dynamic threshold increment

best_distance = float('inf')
best_params = {}

# Load test data once for final evaluation
test_I = np.loadtxt('Data/test_current.csv') # shape (repeats, num_time_steps)
test_v = np.loadtxt('Data/test_traces.csv') # shape (repeats, num_time_steps)
test_spike_times, test_spike_idx = np.loadtxt('Data/test_spikes.csv') # shape (num_spikes,)


# Loop through all combinations of candidate parameters using TRAIN data for tuning
for r_t in candidate_r_timers:
    for s in candidate_scales:
        for t in candidate_taus:
            for thi in candidate_thr_is:
                # Calculate the mean Van Rossum distance for the current parameters using TRAIN data
                current_distance = mean_vr_distance(train_spike_times, train_spike_idx, train_I,
                                                     r_timer=r_t, scale=s, tau=t, thr_i=thi, plot_aprox=False)

                print(f"r_timer: {r_t}, scale: {s}, tau: {t}, thr_i: {thi}, Distance: {current_distance:.4f}")

                # Check if this combination yields a better distance
                if current_distance < best_distance:
                    best_distance = current_distance
                    best_params = {'r_timer': r_t, 'scale': s, 'tau': t, 'thr_i': thi}

print(f"\nBest distance found on training data: {best_distance:.4f}")
print(f"Best parameters: {best_params}")

# Now, evaluate the best parameters on the TEST data for the final competition score
d_best_on_test = mean_vr_distance(test_spike_times, test_spike_idx, test_I, **best_params)
print(f"Final distance with best parameters on TEST data: {d_best_on_test:.4f}")
# Out:
# r_timer: 0.1, scale: 8.0, tau: 3.0, thr_i: 1.0, Distance: 21.3808
# r_timer: 0.1, scale: 8.0, tau: 3.0, thr_i: 2.0, Distance: 16.5955
# r_timer: 0.1, scale: 8.0, tau: 3.0, thr_i: 3.0, Distance: 15.8027
# r_timer: 0.1, scale: 8.0, tau: 3.0, thr_i: 4.0, Distance: 15.8445
# r_timer: 0.1, scale: 8.0, tau: 5.0, thr_i: 1.0, Distance: 17.7564
# r_timer: 0.1, scale: 8.0, tau: 5.0, thr_i: 2.0, Distance: 15.2881
# r_timer: 0.1, scale: 8.0, tau: 5.0, thr_i: 3.0, Distance: 15.2072
# r_timer: 0.1, scale: 8.0, tau: 5.0, thr_i: 4.0, Distance: 15.4840
# r_timer: 0.1, scale: 8.0, tau: 7.0, thr_i: 1.0, Distance: 15.9448
# r_timer: 0.1, scale: 8.0, tau: 7.0, thr_i: 2.0, Distance: 14.7123
# r_timer: 0.1, scale: 8.0, tau: 7.0, thr_i: 3.0, Distance: 14.9658
# r_timer: 0.1, scale: 8.0, tau: 7.0, thr_i: 4.0, Distance: 15.2254
# r_timer: 0.1, scale: 8.0, tau: 10.0, thr_i: 1.0, Distance: 14.3691
# r_timer: 0.1, scale: 8.0, tau: 10.0, thr_i: 2.0, Distance: 14.2714
# r_timer: 0.1, scale: 8.0, tau: 10.0, thr_i: 3.0, Distance: 14.7094
# r_timer: 0.1, scale: 8.0, tau: 10.0, thr_i: 4.0, Distance: 15.0950
# r_timer: 0.1, scale: 10.0, tau: 3.0, thr_i: 1.0, Distance: 24.8349
# r_timer: 0.1, scale: 10.0, tau: 3.0, thr_i: 2.0, Distance: 17.9147
# r_timer: 0.1, scale: 10.0, tau: 3.0, thr_i: 3.0, Distance: 16.2834
# r_timer: 0.1, scale: 10.0, tau: 3.0, thr_i: 4.0, Distance: 15.8566
# r_timer: 0.1, scale: 10.0, tau: 5.0, thr_i: 1.0, Distance: 20.0592
# r_timer: 0.1, scale: 10.0, tau: 5.0, thr_i: 2.0, Distance: 16.0276
# r_timer: 0.1, scale: 10.0, tau: 5.0, thr_i: 3.0, Distance: 15.3083
# r_timer: 0.1, scale: 10.0, tau: 5.0, thr_i: 4.0, Distance: 15.3337
# r_timer: 0.1, scale: 10.0, tau: 7.0, thr_i: 1.0, Distance: 17.5438
# r_timer: 0.1, scale: 10.0, tau: 7.0, thr_i: 2.0, Distance: 14.9871
# r_timer: 0.1, scale: 10.0, tau: 7.0, thr_i: 3.0, Distance: 14.8326
# r_timer: 0.1, scale: 10.0, tau: 7.0, thr_i: 4.0, Distance: 15.1115
# r_timer: 0.1, scale: 10.0, tau: 10.0, thr_i: 1.0, Distance: 15.4247
# r_timer: 0.1, scale: 10.0, tau: 10.0, thr_i: 2.0, Distance: 14.2826
# r_timer: 0.1, scale: 10.0, tau: 10.0, thr_i: 3.0, Distance: 14.5051
# r_timer: 0.1, scale: 10.0, tau: 10.0, thr_i: 4.0, Distance: 14.8599
# r_timer: 0.1, scale: 12.0, tau: 3.0, thr_i: 1.0, Distance: 28.3029
# r_timer: 0.1, scale: 12.0, tau: 3.0, thr_i: 2.0, Distance: 19.5036
# r_timer: 0.1, scale: 12.0, tau: 3.0, thr_i: 3.0, Distance: 17.0317
# r_timer: 0.1, scale: 12.0, tau: 3.0, thr_i: 4.0, Distance: 16.2098
# r_timer: 0.1, scale: 12.0, tau: 5.0, thr_i: 1.0, Distance: 22.4939
# r_timer: 0.1, scale: 12.0, tau: 5.0, thr_i: 2.0, Distance: 16.9574
# r_timer: 0.1, scale: 12.0, tau: 5.0, thr_i: 3.0, Distance: 15.6320
# r_timer: 0.1, scale: 12.0, tau: 5.0, thr_i: 4.0, Distance: 15.3596
# r_timer: 0.1, scale: 12.0, tau: 7.0, thr_i: 1.0, Distance: 19.3227
# r_timer: 0.1, scale: 12.0, tau: 7.0, thr_i: 2.0, Distance: 15.6426
# r_timer: 0.1, scale: 12.0, tau: 7.0, thr_i: 3.0, Distance: 14.9764
# r_timer: 0.1, scale: 12.0, tau: 7.0, thr_i: 4.0, Distance: 14.9641
# r_timer: 0.1, scale: 12.0, tau: 10.0, thr_i: 1.0, Distance: 16.5599
# r_timer: 0.1, scale: 12.0, tau: 10.0, thr_i: 2.0, Distance: 14.5540
# r_timer: 0.1, scale: 12.0, tau: 10.0, thr_i: 3.0, Distance: 14.4788
# r_timer: 0.1, scale: 12.0, tau: 10.0, thr_i: 4.0, Distance: 14.7410
# r_timer: 0.1, scale: 15.0, tau: 3.0, thr_i: 1.0, Distance: 33.3853
# r_timer: 0.1, scale: 15.0, tau: 3.0, thr_i: 2.0, Distance: 22.0853
# r_timer: 0.1, scale: 15.0, tau: 3.0, thr_i: 3.0, Distance: 18.4281
# r_timer: 0.1, scale: 15.0, tau: 3.0, thr_i: 4.0, Distance: 16.9365
# r_timer: 0.1, scale: 15.0, tau: 5.0, thr_i: 1.0, Distance: 26.1726
# r_timer: 0.1, scale: 15.0, tau: 5.0, thr_i: 2.0, Distance: 18.5927
# r_timer: 0.1, scale: 15.0, tau: 5.0, thr_i: 3.0, Distance: 16.4709
# r_timer: 0.1, scale: 15.0, tau: 5.0, thr_i: 4.0, Distance: 15.6642
# r_timer: 0.1, scale: 15.0, tau: 7.0, thr_i: 1.0, Distance: 22.0837
# r_timer: 0.1, scale: 15.0, tau: 7.0, thr_i: 2.0, Distance: 16.7098
# r_timer: 0.1, scale: 15.0, tau: 7.0, thr_i: 3.0, Distance: 15.4043
# r_timer: 0.1, scale: 15.0, tau: 7.0, thr_i: 4.0, Distance: 15.0813
# r_timer: 0.1, scale: 15.0, tau: 10.0, thr_i: 1.0, Distance: 18.5777
# r_timer: 0.1, scale: 15.0, tau: 10.0, thr_i: 2.0, Distance: 15.2642
# r_timer: 0.1, scale: 15.0, tau: 10.0, thr_i: 3.0, Distance: 14.6349
# r_timer: 0.1, scale: 15.0, tau: 10.0, thr_i: 4.0, Distance: 14.5536
# r_timer: 0.1, scale: 18.0, tau: 3.0, thr_i: 1.0, Distance: 38.1046
# r_timer: 0.1, scale: 18.0, tau: 3.0, thr_i: 2.0, Distance: 24.7796
# r_timer: 0.1, scale: 18.0, tau: 3.0, thr_i: 3.0, Distance: 20.0153
# r_timer: 0.1, scale: 18.0, tau: 3.0, thr_i: 4.0, Distance: 17.9015
# r_timer: 0.1, scale: 18.0, tau: 5.0, thr_i: 1.0, Distance: 29.6334
# r_timer: 0.1, scale: 18.0, tau: 5.0, thr_i: 2.0, Distance: 20.4085
# r_timer: 0.1, scale: 18.0, tau: 5.0, thr_i: 3.0, Distance: 17.4074
# r_timer: 0.1, scale: 18.0, tau: 5.0, thr_i: 4.0, Distance: 16.2452
# r_timer: 0.1, scale: 18.0, tau: 7.0, thr_i: 1.0, Distance: 24.9129
# r_timer: 0.1, scale: 18.0, tau: 7.0, thr_i: 2.0, Distance: 18.0220
# r_timer: 0.1, scale: 18.0, tau: 7.0, thr_i: 3.0, Distance: 16.0856
# r_timer: 0.1, scale: 18.0, tau: 7.0, thr_i: 4.0, Distance: 15.2545
# r_timer: 0.1, scale: 18.0, tau: 10.0, thr_i: 1.0, Distance: 20.6184
# r_timer: 0.1, scale: 18.0, tau: 10.0, thr_i: 2.0, Distance: 15.9648
# r_timer: 0.1, scale: 18.0, tau: 10.0, thr_i: 3.0, Distance: 14.7577
# r_timer: 0.1, scale: 18.0, tau: 10.0, thr_i: 4.0, Distance: 14.6379
# r_timer: 0.3, scale: 8.0, tau: 3.0, thr_i: 1.0, Distance: 20.9155
# r_timer: 0.3, scale: 8.0, tau: 3.0, thr_i: 2.0, Distance: 16.4898
# r_timer: 0.3, scale: 8.0, tau: 3.0, thr_i: 3.0, Distance: 15.7722
# r_timer: 0.3, scale: 8.0, tau: 3.0, thr_i: 4.0, Distance: 15.8315
# r_timer: 0.3, scale: 8.0, tau: 5.0, thr_i: 1.0, Distance: 17.4815
# r_timer: 0.3, scale: 8.0, tau: 5.0, thr_i: 2.0, Distance: 15.2172
# r_timer: 0.3, scale: 8.0, tau: 5.0, thr_i: 3.0, Distance: 15.1930
# r_timer: 0.3, scale: 8.0, tau: 5.0, thr_i: 4.0, Distance: 15.4741
# r_timer: 0.3, scale: 8.0, tau: 7.0, thr_i: 1.0, Distance: 15.8031
# r_timer: 0.3, scale: 8.0, tau: 7.0, thr_i: 2.0, Distance: 14.6833
# r_timer: 0.3, scale: 8.0, tau: 7.0, thr_i: 3.0, Distance: 14.9486
# r_timer: 0.3, scale: 8.0, tau: 7.0, thr_i: 4.0, Distance: 15.2333
# r_timer: 0.3, scale: 8.0, tau: 10.0, thr_i: 1.0, Distance: 14.2832
# r_timer: 0.3, scale: 8.0, tau: 10.0, thr_i: 2.0, Distance: 14.2853
# r_timer: 0.3, scale: 8.0, tau: 10.0, thr_i: 3.0, Distance: 14.7222
# r_timer: 0.3, scale: 8.0, tau: 10.0, thr_i: 4.0, Distance: 15.1036
# r_timer: 0.3, scale: 10.0, tau: 3.0, thr_i: 1.0, Distance: 24.2229
# r_timer: 0.3, scale: 10.0, tau: 3.0, thr_i: 2.0, Distance: 17.7628
# r_timer: 0.3, scale: 10.0, tau: 3.0, thr_i: 3.0, Distance: 16.2434
# r_timer: 0.3, scale: 10.0, tau: 3.0, thr_i: 4.0, Distance: 15.8369
# r_timer: 0.3, scale: 10.0, tau: 5.0, thr_i: 1.0, Distance: 19.6884
# r_timer: 0.3, scale: 10.0, tau: 5.0, thr_i: 2.0, Distance: 15.9511
# r_timer: 0.3, scale: 10.0, tau: 5.0, thr_i: 3.0, Distance: 15.2791
# r_timer: 0.3, scale: 10.0, tau: 5.0, thr_i: 4.0, Distance: 15.3148
# r_timer: 0.3, scale: 10.0, tau: 7.0, thr_i: 1.0, Distance: 17.2480
# r_timer: 0.3, scale: 10.0, tau: 7.0, thr_i: 2.0, Distance: 14.9316
# r_timer: 0.3, scale: 10.0, tau: 7.0, thr_i: 3.0, Distance: 14.7919
# r_timer: 0.3, scale: 10.0, tau: 7.0, thr_i: 4.0, Distance: 15.1034
# r_timer: 0.3, scale: 10.0, tau: 10.0, thr_i: 1.0, Distance: 15.2767
# r_timer: 0.3, scale: 10.0, tau: 10.0, thr_i: 2.0, Distance: 14.2998
# r_timer: 0.3, scale: 10.0, tau: 10.0, thr_i: 3.0, Distance: 14.5112
# r_timer: 0.3, scale: 10.0, tau: 10.0, thr_i: 4.0, Distance: 14.8512
# r_timer: 0.3, scale: 12.0, tau: 3.0, thr_i: 1.0, Distance: 27.4154
# r_timer: 0.3, scale: 12.0, tau: 3.0, thr_i: 2.0, Distance: 19.1774
# r_timer: 0.3, scale: 12.0, tau: 3.0, thr_i: 3.0, Distance: 16.9096
# r_timer: 0.3, scale: 12.0, tau: 3.0, thr_i: 4.0, Distance: 16.1713
# r_timer: 0.3, scale: 12.0, tau: 5.0, thr_i: 1.0, Distance: 21.9023
# r_timer: 0.3, scale: 12.0, tau: 5.0, thr_i: 2.0, Distance: 16.7916
# r_timer: 0.3, scale: 12.0, tau: 5.0, thr_i: 3.0, Distance: 15.5383
# r_timer: 0.3, scale: 12.0, tau: 5.0, thr_i: 4.0, Distance: 15.3416
# r_timer: 0.3, scale: 12.0, tau: 7.0, thr_i: 1.0, Distance: 18.9370
# r_timer: 0.3, scale: 12.0, tau: 7.0, thr_i: 2.0, Distance: 15.5272
# r_timer: 0.3, scale: 12.0, tau: 7.0, thr_i: 3.0, Distance: 14.9673
# r_timer: 0.3, scale: 12.0, tau: 7.0, thr_i: 4.0, Distance: 14.9577
# r_timer: 0.3, scale: 12.0, tau: 10.0, thr_i: 1.0, Distance: 16.3238
# r_timer: 0.3, scale: 12.0, tau: 10.0, thr_i: 2.0, Distance: 14.5537
# r_timer: 0.3, scale: 12.0, tau: 10.0, thr_i: 3.0, Distance: 14.4802
# r_timer: 0.3, scale: 12.0, tau: 10.0, thr_i: 4.0, Distance: 14.7649
# r_timer: 0.3, scale: 15.0, tau: 3.0, thr_i: 1.0, Distance: 32.1072
# r_timer: 0.3, scale: 15.0, tau: 3.0, thr_i: 2.0, Distance: 21.6761
# r_timer: 0.3, scale: 15.0, tau: 3.0, thr_i: 3.0, Distance: 18.2524
# r_timer: 0.3, scale: 15.0, tau: 3.0, thr_i: 4.0, Distance: 16.8181
# r_timer: 0.3, scale: 15.0, tau: 5.0, thr_i: 1.0, Distance: 25.3501
# r_timer: 0.3, scale: 15.0, tau: 5.0, thr_i: 2.0, Distance: 18.3265
# r_timer: 0.3, scale: 15.0, tau: 5.0, thr_i: 3.0, Distance: 16.3716
# r_timer: 0.3, scale: 15.0, tau: 5.0, thr_i: 4.0, Distance: 15.5878
# r_timer: 0.3, scale: 15.0, tau: 7.0, thr_i: 1.0, Distance: 21.5395
# r_timer: 0.3, scale: 15.0, tau: 7.0, thr_i: 2.0, Distance: 16.5545
# r_timer: 0.3, scale: 15.0, tau: 7.0, thr_i: 3.0, Distance: 15.3183
# r_timer: 0.3, scale: 15.0, tau: 7.0, thr_i: 4.0, Distance: 15.0853
# r_timer: 0.3, scale: 15.0, tau: 10.0, thr_i: 1.0, Distance: 18.2428
# r_timer: 0.3, scale: 15.0, tau: 10.0, thr_i: 2.0, Distance: 15.1069
# r_timer: 0.3, scale: 15.0, tau: 10.0, thr_i: 3.0, Distance: 14.6069
# r_timer: 0.3, scale: 15.0, tau: 10.0, thr_i: 4.0, Distance: 14.5386
# r_timer: 0.3, scale: 18.0, tau: 3.0, thr_i: 1.0, Distance: 36.4987
# r_timer: 0.3, scale: 18.0, tau: 3.0, thr_i: 2.0, Distance: 24.1776
# r_timer: 0.3, scale: 18.0, tau: 3.0, thr_i: 3.0, Distance: 19.7312
# r_timer: 0.3, scale: 18.0, tau: 3.0, thr_i: 4.0, Distance: 17.7442
# r_timer: 0.3, scale: 18.0, tau: 5.0, thr_i: 1.0, Distance: 28.6139
# r_timer: 0.3, scale: 18.0, tau: 5.0, thr_i: 2.0, Distance: 20.0015
# r_timer: 0.3, scale: 18.0, tau: 5.0, thr_i: 3.0, Distance: 17.2825
# r_timer: 0.3, scale: 18.0, tau: 5.0, thr_i: 4.0, Distance: 16.1766
# r_timer: 0.3, scale: 18.0, tau: 7.0, thr_i: 1.0, Distance: 24.1635
# r_timer: 0.3, scale: 18.0, tau: 7.0, thr_i: 2.0, Distance: 17.7881
# r_timer: 0.3, scale: 18.0, tau: 7.0, thr_i: 3.0, Distance: 15.9640
# r_timer: 0.3, scale: 18.0, tau: 7.0, thr_i: 4.0, Distance: 15.1798
# r_timer: 0.3, scale: 18.0, tau: 10.0, thr_i: 1.0, Distance: 20.1446
# r_timer: 0.3, scale: 18.0, tau: 10.0, thr_i: 2.0, Distance: 15.8127
# r_timer: 0.3, scale: 18.0, tau: 10.0, thr_i: 3.0, Distance: 14.7577
# r_timer: 0.3, scale: 18.0, tau: 10.0, thr_i: 4.0, Distance: 14.6284
# r_timer: 0.5, scale: 8.0, tau: 3.0, thr_i: 1.0, Distance: 20.2483
# r_timer: 0.5, scale: 8.0, tau: 3.0, thr_i: 2.0, Distance: 16.3543
# r_timer: 0.5, scale: 8.0, tau: 3.0, thr_i: 3.0, Distance: 15.7346
# r_timer: 0.5, scale: 8.0, tau: 3.0, thr_i: 4.0, Distance: 15.8107
# r_timer: 0.5, scale: 8.0, tau: 5.0, thr_i: 1.0, Distance: 17.1383
# r_timer: 0.5, scale: 8.0, tau: 5.0, thr_i: 2.0, Distance: 15.1646
# r_timer: 0.5, scale: 8.0, tau: 5.0, thr_i: 3.0, Distance: 15.1740
# r_timer: 0.5, scale: 8.0, tau: 5.0, thr_i: 4.0, Distance: 15.4592
# r_timer: 0.5, scale: 8.0, tau: 7.0, thr_i: 1.0, Distance: 15.5531
# r_timer: 0.5, scale: 8.0, tau: 7.0, thr_i: 2.0, Distance: 14.6242
# r_timer: 0.5, scale: 8.0, tau: 7.0, thr_i: 3.0, Distance: 14.9487
# r_timer: 0.5, scale: 8.0, tau: 7.0, thr_i: 4.0, Distance: 15.2238
# r_timer: 0.5, scale: 8.0, tau: 10.0, thr_i: 1.0, Distance: 14.1828
# r_timer: 0.5, scale: 8.0, tau: 10.0, thr_i: 2.0, Distance: 14.2986
# r_timer: 0.5, scale: 8.0, tau: 10.0, thr_i: 3.0, Distance: 14.7480
# r_timer: 0.5, scale: 8.0, tau: 10.0, thr_i: 4.0, Distance: 15.1042
# r_timer: 0.5, scale: 10.0, tau: 3.0, thr_i: 1.0, Distance: 23.2774
# r_timer: 0.5, scale: 10.0, tau: 3.0, thr_i: 2.0, Distance: 17.4641
# r_timer: 0.5, scale: 10.0, tau: 3.0, thr_i: 3.0, Distance: 16.1149
# r_timer: 0.5, scale: 10.0, tau: 3.0, thr_i: 4.0, Distance: 15.8015
# r_timer: 0.5, scale: 10.0, tau: 5.0, thr_i: 1.0, Distance: 19.0797
# r_timer: 0.5, scale: 10.0, tau: 5.0, thr_i: 2.0, Distance: 15.8295
# r_timer: 0.5, scale: 10.0, tau: 5.0, thr_i: 3.0, Distance: 15.2275
# r_timer: 0.5, scale: 10.0, tau: 5.0, thr_i: 4.0, Distance: 15.3108
# r_timer: 0.5, scale: 10.0, tau: 7.0, thr_i: 1.0, Distance: 16.9021
# r_timer: 0.5, scale: 10.0, tau: 7.0, thr_i: 2.0, Distance: 14.8907
# r_timer: 0.5, scale: 10.0, tau: 7.0, thr_i: 3.0, Distance: 14.7699
# r_timer: 0.5, scale: 10.0, tau: 7.0, thr_i: 4.0, Distance: 15.1154
# r_timer: 0.5, scale: 10.0, tau: 10.0, thr_i: 1.0, Distance: 15.0327
# r_timer: 0.5, scale: 10.0, tau: 10.0, thr_i: 2.0, Distance: 14.2708
# r_timer: 0.5, scale: 10.0, tau: 10.0, thr_i: 3.0, Distance: 14.5250
# r_timer: 0.5, scale: 10.0, tau: 10.0, thr_i: 4.0, Distance: 14.8701
# r_timer: 0.5, scale: 12.0, tau: 3.0, thr_i: 1.0, Distance: 26.2150
# r_timer: 0.5, scale: 12.0, tau: 3.0, thr_i: 2.0, Distance: 18.8163
# r_timer: 0.5, scale: 12.0, tau: 3.0, thr_i: 3.0, Distance: 16.7510
# r_timer: 0.5, scale: 12.0, tau: 3.0, thr_i: 4.0, Distance: 16.0632
# r_timer: 0.5, scale: 12.0, tau: 5.0, thr_i: 1.0, Distance: 21.1406
# r_timer: 0.5, scale: 12.0, tau: 5.0, thr_i: 2.0, Distance: 16.5132
# r_timer: 0.5, scale: 12.0, tau: 5.0, thr_i: 3.0, Distance: 15.4798
# r_timer: 0.5, scale: 12.0, tau: 5.0, thr_i: 4.0, Distance: 15.3071
# r_timer: 0.5, scale: 12.0, tau: 7.0, thr_i: 1.0, Distance: 18.4408
# r_timer: 0.5, scale: 12.0, tau: 7.0, thr_i: 2.0, Distance: 15.4065
# r_timer: 0.5, scale: 12.0, tau: 7.0, thr_i: 3.0, Distance: 14.9084
# r_timer: 0.5, scale: 12.0, tau: 7.0, thr_i: 4.0, Distance: 14.9376
# r_timer: 0.5, scale: 12.0, tau: 10.0, thr_i: 1.0, Distance: 16.1132
# r_timer: 0.5, scale: 12.0, tau: 10.0, thr_i: 2.0, Distance: 14.5231
# r_timer: 0.5, scale: 12.0, tau: 10.0, thr_i: 3.0, Distance: 14.4389
# r_timer: 0.5, scale: 12.0, tau: 10.0, thr_i: 4.0, Distance: 14.7773
# r_timer: 0.5, scale: 15.0, tau: 3.0, thr_i: 1.0, Distance: 30.3498
# r_timer: 0.5, scale: 15.0, tau: 3.0, thr_i: 2.0, Distance: 21.0849
# r_timer: 0.5, scale: 15.0, tau: 3.0, thr_i: 3.0, Distance: 17.9572
# r_timer: 0.5, scale: 15.0, tau: 3.0, thr_i: 4.0, Distance: 16.6856
# r_timer: 0.5, scale: 15.0, tau: 5.0, thr_i: 1.0, Distance: 24.2414
# r_timer: 0.5, scale: 15.0, tau: 5.0, thr_i: 2.0, Distance: 17.9635
# r_timer: 0.5, scale: 15.0, tau: 5.0, thr_i: 3.0, Distance: 16.1814
# r_timer: 0.5, scale: 15.0, tau: 5.0, thr_i: 4.0, Distance: 15.5148
# r_timer: 0.5, scale: 15.0, tau: 7.0, thr_i: 1.0, Distance: 20.7888
# r_timer: 0.5, scale: 15.0, tau: 7.0, thr_i: 2.0, Distance: 16.3040
# r_timer: 0.5, scale: 15.0, tau: 7.0, thr_i: 3.0, Distance: 15.2196
# r_timer: 0.5, scale: 15.0, tau: 7.0, thr_i: 4.0, Distance: 15.0347
# r_timer: 0.5, scale: 15.0, tau: 10.0, thr_i: 1.0, Distance: 17.7319
# r_timer: 0.5, scale: 15.0, tau: 10.0, thr_i: 2.0, Distance: 14.9287
# r_timer: 0.5, scale: 15.0, tau: 10.0, thr_i: 3.0, Distance: 14.5297
# r_timer: 0.5, scale: 15.0, tau: 10.0, thr_i: 4.0, Distance: 14.5542
# r_timer: 0.5, scale: 18.0, tau: 3.0, thr_i: 1.0, Distance: 34.2375
# r_timer: 0.5, scale: 18.0, tau: 3.0, thr_i: 2.0, Distance: 23.3272
# r_timer: 0.5, scale: 18.0, tau: 3.0, thr_i: 3.0, Distance: 19.2956
# r_timer: 0.5, scale: 18.0, tau: 3.0, thr_i: 4.0, Distance: 17.5152
# r_timer: 0.5, scale: 18.0, tau: 5.0, thr_i: 1.0, Distance: 27.1746
# r_timer: 0.5, scale: 18.0, tau: 5.0, thr_i: 2.0, Distance: 19.4902
# r_timer: 0.5, scale: 18.0, tau: 5.0, thr_i: 3.0, Distance: 16.9912
# r_timer: 0.5, scale: 18.0, tau: 5.0, thr_i: 4.0, Distance: 16.0582
# r_timer: 0.5, scale: 18.0, tau: 7.0, thr_i: 1.0, Distance: 23.1268
# r_timer: 0.5, scale: 18.0, tau: 7.0, thr_i: 2.0, Distance: 17.4097
# r_timer: 0.5, scale: 18.0, tau: 7.0, thr_i: 3.0, Distance: 15.8050
# r_timer: 0.5, scale: 18.0, tau: 7.0, thr_i: 4.0, Distance: 15.1183
# r_timer: 0.5, scale: 18.0, tau: 10.0, thr_i: 1.0, Distance: 19.4005
# r_timer: 0.5, scale: 18.0, tau: 10.0, thr_i: 2.0, Distance: 15.6066
# r_timer: 0.5, scale: 18.0, tau: 10.0, thr_i: 3.0, Distance: 14.7163
# r_timer: 0.5, scale: 18.0, tau: 10.0, thr_i: 4.0, Distance: 14.5837
# r_timer: 0.7, scale: 8.0, tau: 3.0, thr_i: 1.0, Distance: 19.8820
# r_timer: 0.7, scale: 8.0, tau: 3.0, thr_i: 2.0, Distance: 16.2605
# r_timer: 0.7, scale: 8.0, tau: 3.0, thr_i: 3.0, Distance: 15.7050
# r_timer: 0.7, scale: 8.0, tau: 3.0, thr_i: 4.0, Distance: 15.8036
# r_timer: 0.7, scale: 8.0, tau: 5.0, thr_i: 1.0, Distance: 16.9318
# r_timer: 0.7, scale: 8.0, tau: 5.0, thr_i: 2.0, Distance: 15.1098
# r_timer: 0.7, scale: 8.0, tau: 5.0, thr_i: 3.0, Distance: 15.1498
# r_timer: 0.7, scale: 8.0, tau: 5.0, thr_i: 4.0, Distance: 15.4477
# r_timer: 0.7, scale: 8.0, tau: 7.0, thr_i: 1.0, Distance: 15.4686
# r_timer: 0.7, scale: 8.0, tau: 7.0, thr_i: 2.0, Distance: 14.6205
# r_timer: 0.7, scale: 8.0, tau: 7.0, thr_i: 3.0, Distance: 14.9417
# r_timer: 0.7, scale: 8.0, tau: 7.0, thr_i: 4.0, Distance: 15.2369
# r_timer: 0.7, scale: 8.0, tau: 10.0, thr_i: 1.0, Distance: 14.1713
# r_timer: 0.7, scale: 8.0, tau: 10.0, thr_i: 2.0, Distance: 14.2909
# r_timer: 0.7, scale: 8.0, tau: 10.0, thr_i: 3.0, Distance: 14.7574
# r_timer: 0.7, scale: 8.0, tau: 10.0, thr_i: 4.0, Distance: 15.1079
# r_timer: 0.7, scale: 10.0, tau: 3.0, thr_i: 1.0, Distance: 22.6207
# r_timer: 0.7, scale: 10.0, tau: 3.0, thr_i: 2.0, Distance: 17.2767
# r_timer: 0.7, scale: 10.0, tau: 3.0, thr_i: 3.0, Distance: 16.0597
# r_timer: 0.7, scale: 10.0, tau: 3.0, thr_i: 4.0, Distance: 15.7751
# r_timer: 0.7, scale: 10.0, tau: 5.0, thr_i: 1.0, Distance: 18.7686
# r_timer: 0.7, scale: 10.0, tau: 5.0, thr_i: 2.0, Distance: 15.7341
# r_timer: 0.7, scale: 10.0, tau: 5.0, thr_i: 3.0, Distance: 15.1924
# r_timer: 0.7, scale: 10.0, tau: 5.0, thr_i: 4.0, Distance: 15.3165
# r_timer: 0.7, scale: 10.0, tau: 7.0, thr_i: 1.0, Distance: 16.6685
# r_timer: 0.7, scale: 10.0, tau: 7.0, thr_i: 2.0, Distance: 14.8564
# r_timer: 0.7, scale: 10.0, tau: 7.0, thr_i: 3.0, Distance: 14.7688
# r_timer: 0.7, scale: 10.0, tau: 7.0, thr_i: 4.0, Distance: 15.1064
# r_timer: 0.7, scale: 10.0, tau: 10.0, thr_i: 1.0, Distance: 14.9990
# r_timer: 0.7, scale: 10.0, tau: 10.0, thr_i: 2.0, Distance: 14.2632
# r_timer: 0.7, scale: 10.0, tau: 10.0, thr_i: 3.0, Distance: 14.5345
# r_timer: 0.7, scale: 10.0, tau: 10.0, thr_i: 4.0, Distance: 14.8766
# r_timer: 0.7, scale: 12.0, tau: 3.0, thr_i: 1.0, Distance: 25.3907
# r_timer: 0.7, scale: 12.0, tau: 3.0, thr_i: 2.0, Distance: 18.5604
# r_timer: 0.7, scale: 12.0, tau: 3.0, thr_i: 3.0, Distance: 16.6319
# r_timer: 0.7, scale: 12.0, tau: 3.0, thr_i: 4.0, Distance: 16.0173
# r_timer: 0.7, scale: 12.0, tau: 5.0, thr_i: 1.0, Distance: 20.6622
# r_timer: 0.7, scale: 12.0, tau: 5.0, thr_i: 2.0, Distance: 16.3965
# r_timer: 0.7, scale: 12.0, tau: 5.0, thr_i: 3.0, Distance: 15.4251
# r_timer: 0.7, scale: 12.0, tau: 5.0, thr_i: 4.0, Distance: 15.2738
# r_timer: 0.7, scale: 12.0, tau: 7.0, thr_i: 1.0, Distance: 18.0868
# r_timer: 0.7, scale: 12.0, tau: 7.0, thr_i: 2.0, Distance: 15.3070
# r_timer: 0.7, scale: 12.0, tau: 7.0, thr_i: 3.0, Distance: 14.8930
# r_timer: 0.7, scale: 12.0, tau: 7.0, thr_i: 4.0, Distance: 14.9328
# r_timer: 0.7, scale: 12.0, tau: 10.0, thr_i: 1.0, Distance: 15.9277
# r_timer: 0.7, scale: 12.0, tau: 10.0, thr_i: 2.0, Distance: 14.4837
# r_timer: 0.7, scale: 12.0, tau: 10.0, thr_i: 3.0, Distance: 14.4210
# r_timer: 0.7, scale: 12.0, tau: 10.0, thr_i: 4.0, Distance: 14.7724
# r_timer: 0.7, scale: 15.0, tau: 3.0, thr_i: 1.0, Distance: 29.2038
# r_timer: 0.7, scale: 15.0, tau: 3.0, thr_i: 2.0, Distance: 20.6990
# r_timer: 0.7, scale: 15.0, tau: 3.0, thr_i: 3.0, Distance: 17.8014
# r_timer: 0.7, scale: 15.0, tau: 3.0, thr_i: 4.0, Distance: 16.6025
# r_timer: 0.7, scale: 15.0, tau: 5.0, thr_i: 1.0, Distance: 23.5321
# r_timer: 0.7, scale: 15.0, tau: 5.0, thr_i: 2.0, Distance: 17.7289
# r_timer: 0.7, scale: 15.0, tau: 5.0, thr_i: 3.0, Distance: 16.0808
# r_timer: 0.7, scale: 15.0, tau: 5.0, thr_i: 4.0, Distance: 15.4734
# r_timer: 0.7, scale: 15.0, tau: 7.0, thr_i: 1.0, Distance: 20.2962
# r_timer: 0.7, scale: 15.0, tau: 7.0, thr_i: 2.0, Distance: 16.1748
# r_timer: 0.7, scale: 15.0, tau: 7.0, thr_i: 3.0, Distance: 15.1645
# r_timer: 0.7, scale: 15.0, tau: 7.0, thr_i: 4.0, Distance: 15.0113
# r_timer: 0.7, scale: 15.0, tau: 10.0, thr_i: 1.0, Distance: 17.4314
# r_timer: 0.7, scale: 15.0, tau: 10.0, thr_i: 2.0, Distance: 14.8210
# r_timer: 0.7, scale: 15.0, tau: 10.0, thr_i: 3.0, Distance: 14.4764
# r_timer: 0.7, scale: 15.0, tau: 10.0, thr_i: 4.0, Distance: 14.5468
# r_timer: 0.7, scale: 18.0, tau: 3.0, thr_i: 1.0, Distance: 32.7677
# r_timer: 0.7, scale: 18.0, tau: 3.0, thr_i: 2.0, Distance: 22.8092
# r_timer: 0.7, scale: 18.0, tau: 3.0, thr_i: 3.0, Distance: 18.9974
# r_timer: 0.7, scale: 18.0, tau: 3.0, thr_i: 4.0, Distance: 17.3581
# r_timer: 0.7, scale: 18.0, tau: 5.0, thr_i: 1.0, Distance: 26.2741
# r_timer: 0.7, scale: 18.0, tau: 5.0, thr_i: 2.0, Distance: 19.1362
# r_timer: 0.7, scale: 18.0, tau: 5.0, thr_i: 3.0, Distance: 16.8464
# r_timer: 0.7, scale: 18.0, tau: 5.0, thr_i: 4.0, Distance: 15.9946
# r_timer: 0.7, scale: 18.0, tau: 7.0, thr_i: 1.0, Distance: 22.4730
# r_timer: 0.7, scale: 18.0, tau: 7.0, thr_i: 2.0, Distance: 17.1919
# r_timer: 0.7, scale: 18.0, tau: 7.0, thr_i: 3.0, Distance: 15.6956
# r_timer: 0.7, scale: 18.0, tau: 7.0, thr_i: 4.0, Distance: 15.0767
# r_timer: 0.7, scale: 18.0, tau: 10.0, thr_i: 1.0, Distance: 19.0113
# r_timer: 0.7, scale: 18.0, tau: 10.0, thr_i: 2.0, Distance: 15.4769
# r_timer: 0.7, scale: 18.0, tau: 10.0, thr_i: 3.0, Distance: 14.7083
# r_timer: 0.7, scale: 18.0, tau: 10.0, thr_i: 4.0, Distance: 14.5573
# r_timer: 1.0, scale: 8.0, tau: 3.0, thr_i: 1.0, Distance: 19.3111
# r_timer: 1.0, scale: 8.0, tau: 3.0, thr_i: 2.0, Distance: 16.1245
# r_timer: 1.0, scale: 8.0, tau: 3.0, thr_i: 3.0, Distance: 15.6822
# r_timer: 1.0, scale: 8.0, tau: 3.0, thr_i: 4.0, Distance: 15.7977
# r_timer: 1.0, scale: 8.0, tau: 5.0, thr_i: 1.0, Distance: 16.5942
# r_timer: 1.0, scale: 8.0, tau: 5.0, thr_i: 2.0, Distance: 15.0685
# r_timer: 1.0, scale: 8.0, tau: 5.0, thr_i: 3.0, Distance: 15.1437
# r_timer: 1.0, scale: 8.0, tau: 5.0, thr_i: 4.0, Distance: 15.4327
# r_timer: 1.0, scale: 8.0, tau: 7.0, thr_i: 1.0, Distance: 15.2845
# r_timer: 1.0, scale: 8.0, tau: 7.0, thr_i: 2.0, Distance: 14.5999
# r_timer: 1.0, scale: 8.0, tau: 7.0, thr_i: 3.0, Distance: 14.9565
# r_timer: 1.0, scale: 8.0, tau: 7.0, thr_i: 4.0, Distance: 15.2410
# r_timer: 1.0, scale: 8.0, tau: 10.0, thr_i: 1.0, Distance: 14.1030
# r_timer: 1.0, scale: 8.0, tau: 10.0, thr_i: 2.0, Distance: 14.2712
# r_timer: 1.0, scale: 8.0, tau: 10.0, thr_i: 3.0, Distance: 14.7741
# r_timer: 1.0, scale: 8.0, tau: 10.0, thr_i: 4.0, Distance: 15.1201
# r_timer: 1.0, scale: 10.0, tau: 3.0, thr_i: 1.0, Distance: 21.7999
# r_timer: 1.0, scale: 10.0, tau: 3.0, thr_i: 2.0, Distance: 17.0484
# r_timer: 1.0, scale: 10.0, tau: 3.0, thr_i: 3.0, Distance: 15.9696
# r_timer: 1.0, scale: 10.0, tau: 3.0, thr_i: 4.0, Distance: 15.7395
# r_timer: 1.0, scale: 10.0, tau: 5.0, thr_i: 1.0, Distance: 18.2638
# r_timer: 1.0, scale: 10.0, tau: 5.0, thr_i: 2.0, Distance: 15.6364
# r_timer: 1.0, scale: 10.0, tau: 5.0, thr_i: 3.0, Distance: 15.1756
# r_timer: 1.0, scale: 10.0, tau: 5.0, thr_i: 4.0, Distance: 15.3213
# r_timer: 1.0, scale: 10.0, tau: 7.0, thr_i: 1.0, Distance: 16.4214
# r_timer: 1.0, scale: 10.0, tau: 7.0, thr_i: 2.0, Distance: 14.8353
# r_timer: 1.0, scale: 10.0, tau: 7.0, thr_i: 3.0, Distance: 14.7562
# r_timer: 1.0, scale: 10.0, tau: 7.0, thr_i: 4.0, Distance: 15.0884
# r_timer: 1.0, scale: 10.0, tau: 10.0, thr_i: 1.0, Distance: 14.8871
# r_timer: 1.0, scale: 10.0, tau: 10.0, thr_i: 2.0, Distance: 14.1986
# r_timer: 1.0, scale: 10.0, tau: 10.0, thr_i: 3.0, Distance: 14.5519
# r_timer: 1.0, scale: 10.0, tau: 10.0, thr_i: 4.0, Distance: 14.9109
# r_timer: 1.0, scale: 12.0, tau: 3.0, thr_i: 1.0, Distance: 24.2506
# r_timer: 1.0, scale: 12.0, tau: 3.0, thr_i: 2.0, Distance: 18.2074
# r_timer: 1.0, scale: 12.0, tau: 3.0, thr_i: 3.0, Distance: 16.5053
# r_timer: 1.0, scale: 12.0, tau: 3.0, thr_i: 4.0, Distance: 15.9537
# r_timer: 1.0, scale: 12.0, tau: 5.0, thr_i: 1.0, Distance: 19.9847
# r_timer: 1.0, scale: 12.0, tau: 5.0, thr_i: 2.0, Distance: 16.2254
# r_timer: 1.0, scale: 12.0, tau: 5.0, thr_i: 3.0, Distance: 15.3303
# r_timer: 1.0, scale: 12.0, tau: 5.0, thr_i: 4.0, Distance: 15.2443
# r_timer: 1.0, scale: 12.0, tau: 7.0, thr_i: 1.0, Distance: 17.6577
# r_timer: 1.0, scale: 12.0, tau: 7.0, thr_i: 2.0, Distance: 15.1846
# r_timer: 1.0, scale: 12.0, tau: 7.0, thr_i: 3.0, Distance: 14.8765
# r_timer: 1.0, scale: 12.0, tau: 7.0, thr_i: 4.0, Distance: 14.9383
# r_timer: 1.0, scale: 12.0, tau: 10.0, thr_i: 1.0, Distance: 15.6493
# r_timer: 1.0, scale: 12.0, tau: 10.0, thr_i: 2.0, Distance: 14.4247
# r_timer: 1.0, scale: 12.0, tau: 10.0, thr_i: 3.0, Distance: 14.4335
# r_timer: 1.0, scale: 12.0, tau: 10.0, thr_i: 4.0, Distance: 14.7661
# r_timer: 1.0, scale: 15.0, tau: 3.0, thr_i: 1.0, Distance: 27.6560
# r_timer: 1.0, scale: 15.0, tau: 3.0, thr_i: 2.0, Distance: 20.1196
# r_timer: 1.0, scale: 15.0, tau: 3.0, thr_i: 3.0, Distance: 17.5419
# r_timer: 1.0, scale: 15.0, tau: 3.0, thr_i: 4.0, Distance: 16.5250
# r_timer: 1.0, scale: 15.0, tau: 5.0, thr_i: 1.0, Distance: 22.5472
# r_timer: 1.0, scale: 15.0, tau: 5.0, thr_i: 2.0, Distance: 17.4490
# r_timer: 1.0, scale: 15.0, tau: 5.0, thr_i: 3.0, Distance: 15.9742
# r_timer: 1.0, scale: 15.0, tau: 5.0, thr_i: 4.0, Distance: 15.3737
# r_timer: 1.0, scale: 15.0, tau: 7.0, thr_i: 1.0, Distance: 19.6071
# r_timer: 1.0, scale: 15.0, tau: 7.0, thr_i: 2.0, Distance: 15.9427
# r_timer: 1.0, scale: 15.0, tau: 7.0, thr_i: 3.0, Distance: 15.0398
# r_timer: 1.0, scale: 15.0, tau: 7.0, thr_i: 4.0, Distance: 14.9462
# r_timer: 1.0, scale: 15.0, tau: 10.0, thr_i: 1.0, Distance: 16.9898
# r_timer: 1.0, scale: 15.0, tau: 10.0, thr_i: 2.0, Distance: 14.7037
# r_timer: 1.0, scale: 15.0, tau: 10.0, thr_i: 3.0, Distance: 14.4281
# r_timer: 1.0, scale: 15.0, tau: 10.0, thr_i: 4.0, Distance: 14.5470
# r_timer: 1.0, scale: 18.0, tau: 3.0, thr_i: 1.0, Distance: 30.8625
# r_timer: 1.0, scale: 18.0, tau: 3.0, thr_i: 2.0, Distance: 21.9956
# r_timer: 1.0, scale: 18.0, tau: 3.0, thr_i: 3.0, Distance: 18.6455
# r_timer: 1.0, scale: 18.0, tau: 3.0, thr_i: 4.0, Distance: 17.1372
# r_timer: 1.0, scale: 18.0, tau: 5.0, thr_i: 1.0, Distance: 24.9965
# r_timer: 1.0, scale: 18.0, tau: 5.0, thr_i: 2.0, Distance: 18.6740
# r_timer: 1.0, scale: 18.0, tau: 5.0, thr_i: 3.0, Distance: 16.6145
# r_timer: 1.0, scale: 18.0, tau: 5.0, thr_i: 4.0, Distance: 15.8620
# r_timer: 1.0, scale: 18.0, tau: 7.0, thr_i: 1.0, Distance: 21.6034
# r_timer: 1.0, scale: 18.0, tau: 7.0, thr_i: 2.0, Distance: 16.9033
# r_timer: 1.0, scale: 18.0, tau: 7.0, thr_i: 3.0, Distance: 15.5708
# r_timer: 1.0, scale: 18.0, tau: 7.0, thr_i: 4.0, Distance: 15.0787
# r_timer: 1.0, scale: 18.0, tau: 10.0, thr_i: 1.0, Distance: 18.4865
# r_timer: 1.0, scale: 18.0, tau: 10.0, thr_i: 2.0, Distance: 15.3461
# r_timer: 1.0, scale: 18.0, tau: 10.0, thr_i: 3.0, Distance: 14.6726
# r_timer: 1.0, scale: 18.0, tau: 10.0, thr_i: 4.0, Distance: 14.4856
#
# Best distance found on training data: 14.1030
# Best parameters: {'r_timer': 1.0, 'scale': 8.0, 'tau': 10.0, 'thr_i': 1.0}
# Distance: 14.299521605105037
# Final distance with best parameters on TEST data: 14.2995

# %%
# Re-initialize best_params_threshold with its full set of values from the kernel state.
# We are using the last known best parameters from the full tuning step:
best_params_threshold_full = {'dt': 0.1, 'r_timer': 1.0, 'tau': 10.0, 'thr_i': 1.0, 'scale': 8.0, 'hyperpolarization_depth': 2.0, 'thr_tau': 50.0, 'threshold': 2.0}

# Extract the best parameters found, excluding hyperpolarization_depth and thr_tau
# We will use the 'threshold' value found.
# The 'scale' needs to be handled separately by mean_vr_distance.

best_params_no_hyper_nor_dynamic_threshold = {
    'r_timer': best_params_threshold_full['r_timer'],
    'tau': best_params_threshold_full['tau'],
    'thr_i': best_params_threshold_full['thr_i'],
    'scale': best_params_threshold_full['scale'], # Pass scale directly to mean_vr_distance
    'threshold': best_params_threshold_full['threshold'] # Include the optimized threshold
}

# Evaluate these parameters using the original mean_vr_distance function,
# which implicitly uses the neuron_model without hyperpolarization.
# Note: The original neuron_model does not have `thr_tau` as a parameter,
# so we remove it from the dictionary explicitly if it was there.
params_for_evaluation = dict(best_params_no_hyper_nor_dynamic_threshold)
if 'thr_tau' in params_for_evaluation:
    params_for_evaluation.pop('thr_tau')
if 'hyperpolarization_depth' in params_for_evaluation:
    params_for_evaluation.pop('hyperpolarization_depth')

# Remove 'scale' from params to pass to neuron_model as it's handled separately by mean_vr_distance
scale_val = params_for_evaluation.pop('scale')

d_no_hyperpolarization = mean_vr_distance(
    test_spike_times, test_spike_idx, test_I,
    scale=scale_val,
    **params_for_evaluation
)

print(f"Final distance with optimized parameters (excluding hyperpolarization and dynamic threshold) on TEST data: {d_no_hyperpolarization:.4f}")
# Out:
# Distance: 13.741868010220612
# Final distance with optimized parameters (excluding hyperpolarization and dynamic threshold) on TEST data: 13.7419

# %%
# Load test data
test_I = np.loadtxt('Data/test_current.csv') # shape (repeats, num_time_steps)
test_v = np.loadtxt('Data/test_traces.csv') # shape (repeats, num_time_steps)
test_spike_times, test_spike_idx = np.loadtxt('Data/test_spikes.csv') # shape (num_spikes,)

# Test model
d = mean_vr_distance(test_spike_times, test_spike_idx, test_I)
# Out:
# Distance: 15.969058844281074
